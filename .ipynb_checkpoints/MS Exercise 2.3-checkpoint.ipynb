# %% [markdown]
# # MSikos Achievement 2 Exercise 2.3: Fundamentals of Visualization Libraries Part 1

# %% [markdown]
# ## 1. Install libraries, set system path, and import dataset from prior exercise

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import os
import seaborn as sns
from matplotlib import pyplot as plt
from datetime import datetime as dt

# %%
# Set system path

path = r'C:\Users\Stony\OneDrive\CareerFoundry\Data Specialization Course\envs\Citi-Bike'

# %%
# Import dataset from prior exercise

df_filtered = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'filtered_data.csv'), index_col = 0)
# Out:
# C:\Users\Stony\AppData\Local\Temp\ipykernel_18052\612698117.py:3: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_filtered = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'filtered_data.csv'), index_col = 0)

# %%
# Validate dataframe created successfully

df_filtered.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'avgTemp'],
#       dtype='object')

# %% [markdown]
# ## 2. Clean and verify the dataframe

# %%
# Verify structure of dataframe

df_filtered.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  BFD29218AB271154  electric_bike  2022-01-21 13:13:43.392
# 1  7C953F2FD7BE1302   classic_bike  2022-01-10 11:30:54.162
# 2  95893ABD40CED4B8  electric_bike  2022-01-26 10:52:43.096
# 3  F853B50772137378   classic_bike  2022-01-03 08:35:48.247
# 4  7590ADF834797B4B   classic_bike  2022-01-22 14:14:23.043
#
#                   ended_at       start_station_name start_station_id  \
# 0  2022-01-21 13:22:31.463  West End Ave & W 107 St          7650.05
# 1  2022-01-10 11:41:43.422             4 Ave & 3 St          4028.04
# 2  2022-01-26 11:06:35.227          1 Ave & E 62 St          6753.08
# 3  2022-01-03 09:10:50.475          2 Ave & E 96 St          7338.02
# 4  2022-01-22 14:34:57.474          6 Ave & W 34 St           6364.1
#
#               end_station_name end_station_id  start_lat  start_lng  \
# 0  Mt Morris Park W & W 120 St        7685.14  40.802117 -73.968181
# 1      Boerum Pl\t& Pacific St        4488.09  40.673746 -73.985649
# 2              5 Ave & E 29 St        6248.06  40.761227 -73.960940
# 3              5 Ave & E 29 St        6248.06  40.783964 -73.947167
# 4              5 Ave & E 29 St        6248.06  40.749640 -73.988050
#
#      end_lat    end_lng member_casual        date  avgTemp
# 0  40.804038 -73.945925        member  2022-01-21     -6.0
# 1  40.688489 -73.991160        member  2022-01-10      1.6
# 2  40.745168 -73.986831        member  2022-01-26     -2.3
# 3  40.745168 -73.986831        member  2022-01-03      1.4
# 4  40.745168 -73.986831        member  2022-01-22     -5.9

# %%
df_filtered.shape
# Out:
# (29838166, 15)

# %%
df_filtered.count
# Out:
# <bound method DataFrame.count of                    ride_id  rideable_type               started_at  \
# 0         BFD29218AB271154  electric_bike  2022-01-21 13:13:43.392
# 1         7C953F2FD7BE1302   classic_bike  2022-01-10 11:30:54.162
# 2         95893ABD40CED4B8  electric_bike  2022-01-26 10:52:43.096
# 3         F853B50772137378   classic_bike  2022-01-03 08:35:48.247
# 4         7590ADF834797B4B   classic_bike  2022-01-22 14:14:23.043
# ...                    ...            ...                      ...
# 29838801  1F223EDAFF420AE3  electric_bike  2022-12-01 20:26:45.847
# 29838802  CFA5C560ACB73B8E   classic_bike  2022-12-26 13:46:34.237
# 29838803  11C8C5E0DB947B07   classic_bike  2022-12-01 05:56:14.903
# 29838804  5B9B083C534A5964   classic_bike  2022-12-02 11:54:15.871
# 29838805  91C286C462F89A50   classic_bike  2022-12-18 13:35:22.574
#
#                          ended_at        start_station_name start_station_id  \
# 0         2022-01-21 13:22:31.463   West End Ave & W 107 St          7650.05
# 1         2022-01-10 11:41:43.422              4 Ave & 3 St          4028.04
# 2         2022-01-26 11:06:35.227           1 Ave & E 62 St          6753.08
# 3         2022-01-03 09:10:50.475           2 Ave & E 96 St          7338.02
# 4         2022-01-22 14:34:57.474           6 Ave & W 34 St           6364.1
# ...                           ...                       ...              ...
# 29838801  2022-12-01 20:30:46.012         Avenue D & E 3 St          5436.09
# 29838802  2022-12-26 13:52:43.900            43 Ave & 47 St          6209.05
# 29838803  2022-12-01 06:06:10.357         Avenue D & E 3 St          5436.09
# 29838804  2022-12-02 12:01:00.747  Montague St & Clinton St          4677.06
# 29838805  2022-12-18 13:37:27.193  Montague St & Clinton St          4677.06
#
#                      end_station_name end_station_id  start_lat  start_lng  \
# 0         Mt Morris Park W & W 120 St        7685.14  40.802117 -73.968181
# 1             Boerum Pl\t& Pacific St        4488.09  40.673746 -73.985649
# 2                     5 Ave & E 29 St        6248.06  40.761227 -73.960940
# 3                     5 Ave & E 29 St        6248.06  40.783964 -73.947167
# 4                     5 Ave & E 29 St        6248.06  40.749640 -73.988050
# ...                               ...            ...        ...        ...
# 29838801     Stanton St & Chrystie St        5523.02  40.720701 -73.977939
# 29838802               39 Ave & 45 St        6401.03  40.744806 -73.917290
# 29838803      Bleecker St & Crosby St        5679.08  40.720828 -73.977932
# 29838804            Sands St & Jay St        4821.03  40.694271 -73.992327
# 29838805  Cadman Plaza E & Tillary St        4677.01  40.694271 -73.992327
#
#             end_lat    end_lng member_casual        date  avgTemp
# 0         40.804038 -73.945925        member  2022-01-21     -6.0
# 1         40.688489 -73.991160        member  2022-01-10      1.6
# 2         40.745168 -73.986831        member  2022-01-26     -2.3
# 3         40.745168 -73.986831        member  2022-01-03      1.4
# 4         40.745168 -73.986831        member  2022-01-22     -5.9
# ...             ...        ...           ...         ...      ...
# 29838801  40.722293 -73.991475        member  2022-12-01      5.7
# 29838802  40.749478 -73.918265        member  2022-12-26     -4.7
# 29838803  40.726156 -73.995102        member  2022-12-01      5.7
# 29838804  40.700119 -73.986200        member  2022-12-02      3.4
# 29838805  40.695977 -73.990149        member  2022-12-18      3.1
#
# [29838166 rows x 15 columns]>

# %%
# Convert date columns date, started_at, and ended_at from object into datetime format

df_filtered['date'] = pd.to_datetime(df_filtered['date'])
df_filtered['started_at'] = pd.to_datetime(df_filtered['started_at'])
df_filtered['ended_at'] = pd.to_datetime(df_filtered['ended_at'])

# %%
# Verify data from 2021 was dropped successfully

df_filtered.groupby(df_filtered.date.dt.year)['started_at'].count()
# Out:
# date
# 2022    29838166
# Name: started_at, dtype: int64

# %%
# Verify format converted successfully

df_filtered.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at            datetime64[ns]
# ended_at              datetime64[ns]
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# date                  datetime64[ns]
# avgTemp                      float64
# dtype: object

# %%
df_filtered.head()
# Out:
#             ride_id  rideable_type              started_at  \
# 0  BFD29218AB271154  electric_bike 2022-01-21 13:13:43.392
# 1  7C953F2FD7BE1302   classic_bike 2022-01-10 11:30:54.162
# 2  95893ABD40CED4B8  electric_bike 2022-01-26 10:52:43.096
# 3  F853B50772137378   classic_bike 2022-01-03 08:35:48.247
# 4  7590ADF834797B4B   classic_bike 2022-01-22 14:14:23.043
#
#                  ended_at       start_station_name start_station_id  \
# 0 2022-01-21 13:22:31.463  West End Ave & W 107 St          7650.05
# 1 2022-01-10 11:41:43.422             4 Ave & 3 St          4028.04
# 2 2022-01-26 11:06:35.227          1 Ave & E 62 St          6753.08
# 3 2022-01-03 09:10:50.475          2 Ave & E 96 St          7338.02
# 4 2022-01-22 14:34:57.474          6 Ave & W 34 St           6364.1
#
#               end_station_name end_station_id  start_lat  start_lng  \
# 0  Mt Morris Park W & W 120 St        7685.14  40.802117 -73.968181
# 1      Boerum Pl\t& Pacific St        4488.09  40.673746 -73.985649
# 2              5 Ave & E 29 St        6248.06  40.761227 -73.960940
# 3              5 Ave & E 29 St        6248.06  40.783964 -73.947167
# 4              5 Ave & E 29 St        6248.06  40.749640 -73.988050
#
#      end_lat    end_lng member_casual       date  avgTemp
# 0  40.804038 -73.945925        member 2022-01-21     -6.0
# 1  40.688489 -73.991160        member 2022-01-10      1.6
# 2  40.745168 -73.986831        member 2022-01-26     -2.3
# 3  40.745168 -73.986831        member 2022-01-03      1.4
# 4  40.745168 -73.986831        member 2022-01-22     -5.9

# %% [markdown]
# ## 3. Create a plot using pandas

# %%
# Create a temporary dataframe using the date column from the merged dataframe

df_temp = df_filtered.set_index('date')

# %%
# Verify temporary dataframe created successfully

df_temp.head()
# Out:
#                      ride_id  rideable_type              started_at  \
# date
# 2022-01-21  BFD29218AB271154  electric_bike 2022-01-21 13:13:43.392
# 2022-01-10  7C953F2FD7BE1302   classic_bike 2022-01-10 11:30:54.162
# 2022-01-26  95893ABD40CED4B8  electric_bike 2022-01-26 10:52:43.096
# 2022-01-03  F853B50772137378   classic_bike 2022-01-03 08:35:48.247
# 2022-01-22  7590ADF834797B4B   classic_bike 2022-01-22 14:14:23.043
#
#                           ended_at       start_station_name start_station_id  \
# date
# 2022-01-21 2022-01-21 13:22:31.463  West End Ave & W 107 St          7650.05
# 2022-01-10 2022-01-10 11:41:43.422             4 Ave & 3 St          4028.04
# 2022-01-26 2022-01-26 11:06:35.227          1 Ave & E 62 St          6753.08
# 2022-01-03 2022-01-03 09:10:50.475          2 Ave & E 96 St          7338.02
# 2022-01-22 2022-01-22 14:34:57.474          6 Ave & W 34 St           6364.1
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# date
# 2022-01-21  Mt Morris Park W & W 120 St        7685.14  40.802117 -73.968181
# 2022-01-10      Boerum Pl\t& Pacific St        4488.09  40.673746 -73.985649
# 2022-01-26              5 Ave & E 29 St        6248.06  40.761227 -73.960940
# 2022-01-03              5 Ave & E 29 St        6248.06  40.783964 -73.947167
# 2022-01-22              5 Ave & E 29 St        6248.06  40.749640 -73.988050
#
#               end_lat    end_lng member_casual  avgTemp
# date
# 2022-01-21  40.804038 -73.945925        member     -6.0
# 2022-01-10  40.688489 -73.991160        member      1.6
# 2022-01-26  40.745168 -73.986831        member     -2.3
# 2022-01-03  40.745168 -73.986831        member      1.4
# 2022-01-22  40.745168 -73.986831        member     -5.9

# %%
# Set the value of agg.path.chunksize to a number greater than 100
plt.rcParams['agg.path.chunksize'] = 100000

# adjusting the path simplification threshold
plt.rcParams['path.simplify_threshold'] = 1.0

# Set the figure size to make the plot wider
plt.figure(figsize=(12, 6))  
plt.title('Temperatures daily for 2022')

# plotting the data
df_temp['avgTemp'].plot()
plt.show()

# %% [markdown]
# ## 4. Create a new column "Count of trips" and merge with existing dataframe

# %%
df_temp.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'avgTemp'],
#       dtype='object')

# %%
# Groupby the count of the trips 

df_group = pd.DataFrame(df_temp.groupby(['date'])['ride_id'].count()).reset_index()

# %%
df_group.rename(columns = {'ride_id':'bike_rides_daily'}, inplace = True)

# %%
df_group.columns
# Out:
# Index(['date', 'bike_rides_daily'], dtype='object')

# %%
df = df_filtered.merge(df_group, on = "date", how = 'outer', indicator = True)
print(df['_merge'].value_counts(dropna = False))
print("Shape of January 1st is", df[df['date'] == '2022-01-01'].shape) # Check 
print("Shape of January 2nd is", df[df['date'] == '2022-01-02'].shape) # Second check 

df_temp = df.set_index('date')

print(df_temp.columns)
# Out:
# _merge
# both          29838166
# left_only            0
# right_only           0
# Name: count, dtype: int64
# Shape of January 1st is (20428, 17)
# Shape of January 2nd is (43009, 17)
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'avgTemp', 'bike_rides_daily', '_merge'],
#       dtype='object')

# %% [markdown]
# ## 5. Plotting rides per day and temperature

# %% [markdown]
# ### Initial plot

# %%
# first try the plot of the bike rides

plt.figure(figsize=(12,6))
plt.title('Daily bike trips')
plt.plot(df_temp['bike_rides_daily'], color = 'navy')
plt.show()

# %%
# Create figure and axis objects with subplots() and details

fig,ax = plt.subplots(2, figsize =(8, 6))

# Make a plot of the bike rides
ax[0].plot(df_temp['bike_rides_daily'],color = "navy")
ax[0].set_ylabel("Bike rides daily",color = "navy", fontsize = 14) # set y-axis label

# Make a plot with the temperatues on the y-axis using second axis object
ax[1].plot(df_temp["avgTemp"], color = "red")
ax[1].set_ylabel("Average temperatures", color = "red",fontsize=14)
plt.suptitle('Temperature and trips in 2022', fontsize = 18)

plt.show()

# %%
# save the plot as a file

fig.savefig(os.path.join(path, '04 Analysis', 'trips_temperatures_dual_line.jpg'),
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# To create the visualization above, I decided to create a plot and subplot to keep the average temperature and number of rides seperate. The first line in the code creates the subplot, the number of plots and the size plots should be. The lines with ax[0] sets the data to be plotted on the y-axis, which is the number of bike rides per month and the legend for the axis. Lines with ax[1] refer to the second plot and define the data points to be plotted as well as the legend for the y-axis. The title for the both subplots was created using the plt.suptitle code.

# %% [markdown]
# # Bonus Task

# %%
df_temp
# Out:
#                      ride_id  rideable_type              started_at  \
# date
# 2022-01-01  4A091640AEC83471   classic_bike 2022-01-01 16:01:22.082
# 2022-01-01  7A560D6287C00126   classic_bike 2022-01-01 14:07:04.344
# 2022-01-01  4F6F726B809C15E4   classic_bike 2022-01-01 12:02:26.943
# 2022-01-01  3BC10DC94FD79955   classic_bike 2022-01-01 22:53:23.508
# 2022-01-01  FE4CE7F1CFFD7952   classic_bike 2022-01-01 08:04:51.755
# ...                      ...            ...                     ...
# 2022-12-31  F2C4F070A50F9F3B   classic_bike 2022-12-31 13:09:50.131
# 2022-12-31  79F3ED73A2BF585C   classic_bike 2022-12-31 17:33:04.512
# 2022-12-31  DDED85920D307CE1   classic_bike 2022-12-31 09:14:53.652
# 2022-12-31  98C9073F2BD6A968   classic_bike 2022-12-31 11:08:40.394
# 2022-12-31  4ACAA87B0BAD4FFF  electric_bike 2022-12-31 05:08:13.457
#
#                           ended_at  \
# date
# 2022-01-01 2022-01-01 16:05:11.986
# 2022-01-01 2022-01-01 14:31:57.500
# 2022-01-01 2022-01-01 12:14:13.555
# 2022-01-01 2022-01-01 23:18:42.881
# 2022-01-01 2022-01-01 08:08:07.290
# ...                            ...
# 2022-12-31 2022-12-31 13:35:28.984
# 2022-12-31 2022-12-31 17:37:56.886
# 2022-12-31 2022-12-31 09:21:11.859
# 2022-12-31 2022-12-31 11:22:18.629
# 2022-12-31 2022-12-31 05:14:43.204
#
#                                        start_station_name start_station_id  \
# date
# 2022-01-01                             S 4 St & Wythe Ave          5204.05
# 2022-01-01                       Lexington Ave & E 120 St          7652.04
# 2022-01-01                       Lexington Ave & E 120 St          7652.04
# 2022-01-01                       Cleveland Pl & Spring St          5492.05
# 2022-01-01  Central Park North & Adam Clayton Powell Blvd          7617.07
# ...                                                   ...              ...
# 2022-12-31                            White St & Moore St          4987.06
# 2022-12-31                           Division St & Bowery          5270.08
# 2022-12-31                               W 30 St & 10 Ave          6459.07
# 2022-12-31                                  5 Ave & 37 St          3379.03
# 2022-12-31                               W 30 St & 10 Ave          6459.07
#
#                     end_station_name end_station_id  start_lat  start_lng  \
# date
# 2022-01-01        Kent Ave & S 11 St        5062.01  40.712859 -73.965903
# 2022-01-01  Amsterdam Ave & W 125 St        7800.03  40.801307 -73.939817
# 2022-01-01  Amsterdam Ave & W 125 St        7800.03  40.801307 -73.939817
# 2022-01-01       Mott St & Prince St        5561.04  40.722104 -73.997249
# 2022-01-01    E 110 St & Madison Ave        7587.14  40.799484 -73.955613
# ...                              ...            ...        ...        ...
# 2022-12-31   Bleecker St & Crosby St        5679.08  40.704508 -73.935100
# 2022-12-31   Centre St & Chambers St        5207.01  40.714193 -73.996732
# 2022-12-31           W 20 St & 8 Ave        6224.05  40.752694 -74.002353
# 2022-12-31              6 Ave & 9 St        3803.09  40.652657 -74.002356
# 2022-12-31           W 20 St & 8 Ave        6224.05  40.752840 -74.002842
#
#               end_lat    end_lng member_casual  avgTemp  bike_rides_daily  \
# date
# 2022-01-01  40.707645 -73.968415        member     11.6             20428
# 2022-01-01  40.813358 -73.956461        member     11.6             20428
# 2022-01-01  40.813358 -73.956461        member     11.6             20428
# 2022-01-01  40.723180 -73.994800        member     11.6             20428
# 2022-01-01  40.796154 -73.947821        member     11.6             20428
# ...               ...        ...           ...      ...               ...
# 2022-12-31  40.726156 -73.995102        member      8.2             31466
# 2022-12-31  40.712733 -74.004607        member      8.2             31466
# 2022-12-31  40.743453 -74.000040        member      8.2             31466
# 2022-12-31  40.668127 -73.983776        member      8.2             31466
# 2022-12-31  40.743453 -74.000040        member      8.2             31466
#
#            _merge
# date
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both
# ...           ...
# 2022-12-31   both
# 2022-12-31   both
# 2022-12-31   both
# 2022-12-31   both
# 2022-12-31   both
#
# [29838166 rows x 16 columns]

# %%
df_temp.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at            datetime64[ns]
# ended_at              datetime64[ns]
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# avgTemp                      float64
# bike_rides_daily               int64
# _merge                      category
# dtype: object

# %%
df_temp['trip_duration'] = df_temp['ended_at'] - df_temp['started_at']

# %%
df_temp.head()
# Out:
#                      ride_id rideable_type              started_at  \
# date
# 2022-01-01  4A091640AEC83471  classic_bike 2022-01-01 16:01:22.082
# 2022-01-01  7A560D6287C00126  classic_bike 2022-01-01 14:07:04.344
# 2022-01-01  4F6F726B809C15E4  classic_bike 2022-01-01 12:02:26.943
# 2022-01-01  3BC10DC94FD79955  classic_bike 2022-01-01 22:53:23.508
# 2022-01-01  FE4CE7F1CFFD7952  classic_bike 2022-01-01 08:04:51.755
#
#                           ended_at  \
# date
# 2022-01-01 2022-01-01 16:05:11.986
# 2022-01-01 2022-01-01 14:31:57.500
# 2022-01-01 2022-01-01 12:14:13.555
# 2022-01-01 2022-01-01 23:18:42.881
# 2022-01-01 2022-01-01 08:08:07.290
#
#                                        start_station_name start_station_id  \
# date
# 2022-01-01                             S 4 St & Wythe Ave          5204.05
# 2022-01-01                       Lexington Ave & E 120 St          7652.04
# 2022-01-01                       Lexington Ave & E 120 St          7652.04
# 2022-01-01                       Cleveland Pl & Spring St          5492.05
# 2022-01-01  Central Park North & Adam Clayton Powell Blvd          7617.07
#
#                     end_station_name end_station_id  start_lat  start_lng  \
# date
# 2022-01-01        Kent Ave & S 11 St        5062.01  40.712859 -73.965903
# 2022-01-01  Amsterdam Ave & W 125 St        7800.03  40.801307 -73.939817
# 2022-01-01  Amsterdam Ave & W 125 St        7800.03  40.801307 -73.939817
# 2022-01-01       Mott St & Prince St        5561.04  40.722104 -73.997249
# 2022-01-01    E 110 St & Madison Ave        7587.14  40.799484 -73.955613
#
#               end_lat    end_lng member_casual  avgTemp  bike_rides_daily  \
# date
# 2022-01-01  40.707645 -73.968415        member     11.6             20428
# 2022-01-01  40.813358 -73.956461        member     11.6             20428
# 2022-01-01  40.813358 -73.956461        member     11.6             20428
# 2022-01-01  40.723180 -73.994800        member     11.6             20428
# 2022-01-01  40.796154 -73.947821        member     11.6             20428
#
#            _merge          trip_duration
# date
# 2022-01-01   both 0 days 00:03:49.904000
# 2022-01-01   both 0 days 00:24:53.156000
# 2022-01-01   both 0 days 00:11:46.612000
# 2022-01-01   both 0 days 00:25:19.373000
# 2022-01-01   both 0 days 00:03:15.535000

# %%
df_temp.dtypes
# Out:
# ride_id                        object
# rideable_type                  object
# started_at             datetime64[ns]
# ended_at               datetime64[ns]
# start_station_name             object
# start_station_id               object
# end_station_name               object
# end_station_id                 object
# start_lat                     float64
# start_lng                     float64
# end_lat                       float64
# end_lng                       float64
# member_casual                  object
# avgTemp                       float64
# bike_rides_daily                int64
# _merge                       category
# trip_duration         timedelta64[ns]
# dtype: object

# %%
df_temp['duration'] = df_temp['trip_duration'].dt.total_seconds() / 60

# %%
df_temp.dtypes
# Out:
# ride_id                        object
# rideable_type                  object
# started_at             datetime64[ns]
# ended_at               datetime64[ns]
# start_station_name             object
# start_station_id               object
# end_station_name               object
# end_station_id                 object
# start_lat                     float64
# start_lng                     float64
# end_lat                       float64
# end_lng                       float64
# member_casual                  object
# avgTemp                       float64
# bike_rides_daily                int64
# _merge                       category
# trip_duration         timedelta64[ns]
# duration                      float64
# dtype: object

# %%
df_temp['duration'].value_counts()
# Out:
# duration
# 5.127317      59
# 4.932033      59
# 5.229233      58
# 4.782150      58
# 5.453750      58
#               ..
# 68.801667      1
# 37.411383      1
# 45.868433      1
# 101.699200     1
# 72.445467      1
# Name: count, Length: 3384866, dtype: int64

# %%
# Plot the sample

plt.hist(df_temp['duration'], bins=10, edgecolor='k', log = True)  # Adjust 'bins' as needed
plt.xlabel('Trip duration')
plt.ylabel('Frequency')
plt.title('Histogram of Sampled Trip Duration')
plt.show()

# %%
# Create a histogram with a density plot
sns.histplot(df_temp['duration'], bins = 10, log = True)

# Add labels and title
plt.xlabel('Trip duration')
plt.ylabel('Frequency')
plt.title('Histogram of Trip Duration')

# Display the plot
plt.show()

# %%
# Generate random data for the histogram
data = df_temp['duration']
 
# Plotting a basic histogram
plt.hist(data, bins=10, color='skyblue', edgecolor='black')
 
# Adding labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Basic Histogram')
 
# Display the plot
plt.show()

# %%
df_temp['duration'].value_counts()
# Out:
# duration
# 5.127317      59
# 4.932033      59
# 5.229233      58
# 4.782150      58
# 5.453750      58
#               ..
# 68.801667      1
# 37.411383      1
# 45.868433      1
# 101.699200     1
# 72.445467      1
# Name: count, Length: 3384866, dtype: int64

# %%
# Verify data from 2021 was dropped successfully
df_temp['started_at'].groupby(df_temp.started_at.dt.year).count()
# Out:
# started_at
# 2022    29838166
# Name: started_at, dtype: int64
