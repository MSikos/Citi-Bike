# %% [markdown]
# # MSikos Achievement 2 Exercise 2.4: Fundamentals of Visualization Libraries Part 2

# %% [markdown]
# ## 1. Import libraries, set system path, and import dataset

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import os
import seaborn as sns
from matplotlib import pyplot as plt
from datetime import datetime as dt

# %%
# Set system path

path = r'C:\Users\Stony\OneDrive\CareerFoundry\Data Specialization Course\envs\Citi-Bike'

# %%
# Import dataset from prior exercise

df_cleaned = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'cleaned_data.csv'), index_col = 0)
# Out:
# C:\Users\Stony\AppData\Local\Temp\ipykernel_21808\3866463880.py:3: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_cleaned = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'cleaned_data.csv'), index_col = 0)

# %%
# Validate dataframe imported successfully

df_cleaned.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'avgTemp', 'bike_rides_daily', '_merge'],
#       dtype='object')

# %%
df_cleaned.head()
# Out:
#                      ride_id rideable_type               started_at  \
# date
# 2022-01-01  4A091640AEC83471  classic_bike  2022-01-01 16:01:22.082
# 2022-01-01  7A560D6287C00126  classic_bike  2022-01-01 14:07:04.344
# 2022-01-01  4F6F726B809C15E4  classic_bike  2022-01-01 12:02:26.943
# 2022-01-01  3BC10DC94FD79955  classic_bike  2022-01-01 22:53:23.508
# 2022-01-01  FE4CE7F1CFFD7952  classic_bike  2022-01-01 08:04:51.755
#
#                            ended_at  \
# date
# 2022-01-01  2022-01-01 16:05:11.986
# 2022-01-01  2022-01-01 14:31:57.500
# 2022-01-01  2022-01-01 12:14:13.555
# 2022-01-01  2022-01-01 23:18:42.881
# 2022-01-01  2022-01-01 08:08:07.290
#
#                                        start_station_name start_station_id  \
# date
# 2022-01-01                             S 4 St & Wythe Ave          5204.05
# 2022-01-01                       Lexington Ave & E 120 St          7652.04
# 2022-01-01                       Lexington Ave & E 120 St          7652.04
# 2022-01-01                       Cleveland Pl & Spring St          5492.05
# 2022-01-01  Central Park North & Adam Clayton Powell Blvd          7617.07
#
#                     end_station_name end_station_id  start_lat  start_lng  \
# date
# 2022-01-01        Kent Ave & S 11 St        5062.01  40.712859 -73.965903
# 2022-01-01  Amsterdam Ave & W 125 St        7800.03  40.801307 -73.939817
# 2022-01-01  Amsterdam Ave & W 125 St        7800.03  40.801307 -73.939817
# 2022-01-01       Mott St & Prince St        5561.04  40.722104 -73.997249
# 2022-01-01    E 110 St & Madison Ave        7587.14  40.799484 -73.955613
#
#               end_lat    end_lng member_casual  avgTemp  bike_rides_daily  \
# date
# 2022-01-01  40.707645 -73.968415        member     11.6             20428
# 2022-01-01  40.813358 -73.956461        member     11.6             20428
# 2022-01-01  40.813358 -73.956461        member     11.6             20428
# 2022-01-01  40.723180 -73.994800        member     11.6             20428
# 2022-01-01  40.796154 -73.947821        member     11.6             20428
#
#            _merge
# date
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both

# %% [markdown]
# ## 2. Create a dual-axis plot with Seaborn

# %%
fig,ax = plt.subplots(figsize=(14, 6))
sns.lineplot(data = df_cleaned['bike_rides_daily'], color = "b")
ax.set_xlabel("Year 2022", fontsize = 14) # set x-axis label
ax.set_ylabel("Bike rides daily",color = "navy", fontsize = 14) # set y-axis label

ax2 = ax.twinx()
sns.lineplot(data = df_cleaned['avgTemp'], color="r", ax=ax2)
ax2.set_ylabel("Average temperatures", color = "red",fontsize=14)
plt.title('Temperature and trips in 2022', fontsize = 18)
plt.show()

# %% [markdown]
# ## 3. Picking one theme, style, and palette

# %%
sns.set_theme(style = "ticks", palette = "BuGn_r")

# %% [markdown]
# ## 4 Create a bar chart of the 20 most popular starting stations

# %%
df_cleaned['value'] = 1

# %%
df_t = df_cleaned.groupby('start_station_name')['value'].count().reset_index()
df_t
# Out:
#                 start_station_name  value
# 0                 1 Ave & E 110 St  21526
# 1                  1 Ave & E 16 St  67349
# 2                  1 Ave & E 18 St  70854
# 3                  1 Ave & E 30 St  45412
# 4                  1 Ave & E 39 St  52373
# ...                            ...    ...
# 1756       Wyckoff Ave & Gates Ave  16556
# 1757            Wyckoff St & 3 Ave    250
# 1758        Wyckoff St & Nevins St  11527
# 1759  Wythe Ave & Metropolitan Ave  66468
# 1760         Yankee Ferry Terminal  12913
#
# [1761 rows x 2 columns]

# %%
# Create a subset of the data containing only the top 20 stations

top20 = df_t.nlargest(20, 'value')
top20
# Out:
#             start_station_name   value
# 1587           W 21 St & 6 Ave  129016
# 1718     West St & Chambers St  123289
# 495         Broadway & W 58 St  114293
# 286            6 Ave & W 33 St  106440
# 8              1 Ave & E 68 St  104856
# 461         Broadway & E 14 St   98862
# 485         Broadway & W 25 St   98422
# 1511   University Pl & E 14 St   97120
# 463         Broadway & E 21 St   95691
# 1603           W 31 St & 7 Ave   94208
# 788            E 33 St & 1 Ave   91003
# 590   Cleveland Pl & Spring St   90973
# 29            12 Ave & W 40 St   90414
# 287            6 Ave & W 34 St   89683
# 1719      West St & Liberty St   87657
# 24            11 Ave & W 41 St   87577
# 1105     Lafayette St & E 8 St   87457
# 562     Central Park S & 6 Ave   87013
# 796         E 40 St & Park Ave   85598
# 328            8 Ave & W 33 St   85051

# %%
# Create a bar chart of the top 20 stations

sns.barplot(data = top20, x = 'value', y = 'start_station_name')
plt.title(" 20 most frequent start stations")
plt.show()

# %%
plt.figure(figsize = (10, 5))
with sns.color_palette('BuGn_r', n_colors = 20):
    sns.barplot(data = top20, x = 'value', y = 'start_station_name').set_title("20 most frequent start stations")
